# %% [markdown]
# ### create Depp Learning project from end to end till development
#
#  1. Create a vgg19 model for classifying imagenet images
#  2. will create a flask app to upload the image(simple HTML)
#  3. Predict from the flask app with the images that we upload

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
# if we take the default it will select the  parameter as they are 
# and keep in mind we are taking weights as imagenet

model=VGG19(weights='imagenet')
# Out:
# ...
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 3207s 6us/step

# %%
model.save("vgg19.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
